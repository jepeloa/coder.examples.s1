# %%
from pandasai import PandasAI
import pandas as pd
from pandasai.llm.openai import OpenAI
import warnings
warnings.filterwarnings('ignore')

# %%
llm=OpenAI(api_token='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')

# %%
pandasai=PandasAI(llm)

# %%
df = pd.read_csv('./dataset_calidad_de_vida.csv')
df.head()
# Out:
#         País  Cantidad de habitantes  Índice de calidad de vida
# 0  Argentina               283471250                       7.92
# 1     Brasil               202175402                       7.59
# 2      Chile                79191392                       3.55
# 3   Colombia                91106897                       1.40
# 4    Ecuador                15585653                       0.66

# %%
pandasai.run(df,'Cual es el pais con mejor calidad de vida')
# Out:
# 'El país con mejor calidad de vida es Costa Rica.'

# %%
pandasai.run(df,'Podes hacer un grafico de barras con los paises con mejor calidad de vida')

# %%
pandasai.run(df,'Podes hacer un grafico de barras con los paises con mejor calidad de vida, cada barra debe tener un color distinto, el titulo debe ser indice de calidad de vida')

# %%
pandasai.run(df,'Podes hacer un grafico de barras utilizando plotly con los paises con mejor calidad de vida, cada barra debe tener un color distinto, el titulo debe ser indice de calidad de vida')
