# %%
from pandasai import PandasAI
import pandas as pd
from pandasai.llm.openai import OpenAI
import warnings
warnings.filterwarnings('ignore')

# %%
llm=OpenAI(api_token='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')

# %%
pandasai=PandasAI(llm)

# %%
df = pd.read_csv('./dataset_calidad_de_vida.csv')

# %%
pandasai.run(df,'Cual es el pais con mejor calidad de vida')
# Out:
# 'El país con mejor calidad de vida es Costa Rica.'

# %%
pandasai.run(df,'Podes hacer un grafico de barras con los paises con mejor calidad de vida')

# %%
pandasai.run(df,'Podes hacer un grafico tipo scatter con los paises con mejor calidad de vida')

# %%
pandasai.run(df,'Podes hacer un grafico tipo scatter y unir las lineas con los paises con mejor calidad de vida')
# Out:
# 'Unfortunately, I was not able to answer your question, because of the following error:\n\nIncorrect API key provided: sk-E9CzX***************************************7IsI. You can find your API key at https://platform.openai.com/account/api-keys.\n'
